# %% [markdown]
# **DATE**: 1 August 2017 <br>
# **ENVIRONMENT**: calour <br>
# **AUTHOR**: Max Abramson

# %%
import calour as ca
import pandas as pd
# %matplotlib notebook

# %%
alt=ca.read("/Users/maxabramson/Desktop/Knight_Lab/AGP_depression/AGP_broad_criteria/Parse_biom_table/filtered_bc_table_222.biom", 
            "/Users/maxabramson/Desktop/Knight_Lab/AGP_depression/AGP_broad_criteria/AGP_bc_subset_metadata_222.txt", normalize = 1000)

# %%
altexp=alt.cluster_features(10)
ca.filtering.filter_samples(altexp, "case", 
                            "not applicable", negate=True, inplace=True)
ca.sorting.sort_samples(altexp, 'collection_timestamp', inplace=True)
altexp.plot_sort('case', sample_color_bars = ['case'], 
                 feature_field = 'taxonomy', gui= 'jupyter', 
                 color_bar_label = False, inplace=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
diff=ca.analysis.diff_abundance(altexp, "case", "case", "control", alpha=0.3, numperm=10000)

# %%
diff
# Out:
# Experiment filtered_bc_table_222.biom with 222 samples, 5 features

# %%
diff.plot_sort('case', sample_color_bars=['case'], 
               feature_fields='taxonomy', gui='jupyter', color_bar_label=False)
# Out:
# <img src="data:image/png;base64,..." width="640">
